# %% [markdown]
# ## Imports

# %% [markdown]
# Install all the necessary package

# %%
pip install pandas numpy tensorflow matplotlib seaborn folium pickle-mixin scikit-learn networkx geopy

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import pickle
import shutil
from google.colab import drive
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix
import networkx as nx
from networkx.algorithms.community import louvain_communities
from geopy.distance import geodesic

# %% [markdown]
# ## loading the data and prepearing it

# %% [markdown]
# ### connect to the drive

# %% [markdown]
# Connect to the drive to get the xlsx file, but this is for the developers

# %%
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/avner/DivvyTripsByQuarter.xlsx'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### create the list of the sheets

# %% [markdown]
# This code creates a list called sheets_list and iterates through the first four sheets of the Excel file, adding each sheet as a DataFrame to the list. For each sheet, the 'GENDER' and 'BIRTH YEAR' columns are dropped. After processing the individual sheets, all the DataFrames in the list are concatenated into a single DataFrame, which is then added to the list. Finally, the concatenated DataFrame, which contains the data from all four quarters, is assigned to the variable data.

# %%
sheets_list = []
for i in range(4):
  sheets_list.append(pd.read_excel(file_path,i))
for index,sheet in enumerate(sheets_list):
  sheet.drop(['GENDER','BIRTH YEAR'],axis=1,inplace=True)

sheets_list.append(pd.concat(sheets_list, ignore_index = True))

#asign the last one to use the data of all the Quarters
data = sheets_list[4].copy()

# %% [markdown]
# ### make graphs to get the commuinites

# %% [markdown]
# This code creates a list of directed graphs (`graphs_list`), where each graph represents the relationships between source and target nodes derived from the sheets in `sheets_list`. For each sheet, it iterates through the rows, adding nodes with geographical and socioeconomic attributes and creating or updating weighted edges based on the frequency of connections between nodes. Each graph corresponds to a single sheet, capturing the relationships and attributes within that data.

# %%
graphs_list = []
for sheet in sheets_list:
  G = nx.DiGraph()
  for index, row in sheet.iterrows():
      source = row['source']
      target = row['target']

      if source not in G:
          G.add_node(source,
                    latitude=row['FROM LATITUDE'],
                    longitude=row['FROM LONGITUDE'],
                    location=row['FROM LOCATION'],
                    area=row['SourceArea'],
                    median_income=row['SourceMedianIncome'],
                    proximity_index=row['SourceProximityIndex'])

      if target not in G:
          G.add_node(target,
                    latitude=row['TO LATITUDE'],
                    longitude=row['TO LONGITUDE'],
                    location=row['TO LOCATION'],
                    area=row['TargetArea'],
                    median_income=row['TargetMedianIncome'],
                    proximity_index=row['TargetProximityIndex'])

      if G.has_edge(source, target):
          G[source][target]['weight'] += 1
      else:
          G.add_edge(source, target, weight=1)
  graphs_list.append(G)

# %% [markdown]
# ### create the commuintys

# %% [markdown]
# This code performs community detection on a directed graph and visualizes the results on a Folium map. It starts by selecting a specific graph from the graphs_list and its corresponding data from sheets_list. Using the Louvain method, communities within the graph are detected, and each node in the DataFrame is assigned to a community. The code calculates the geographic centroid and radius for each community based on the latitude and longitude of its nodes. A Folium map is then created, centered around the average location of all centroids. Each community's nodes are represented by colored circle markers on the map, with centroids and radius circles also plotted. The final map is saved as an HTML file (communities_map.html) and displayed.

# %%
# Assume graphs_list and df_list are predefined and each node has 'latitude' and 'longitude' attributes
graph = graphs_list[4]
data = sheets_list[4].copy()

# Detect communities
communities = list(louvain_communities(graph.to_undirected()))

# Add a new column to the DataFrame to store community assignments
data['Community'] = -1

# Calculate the centroid (center longitude and latitude) of each community and the radius
centroids = []
radii = []
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen']

for i, community in enumerate(communities):
    longitudes = []
    latitudes = []
    for node in community:
        # Assuming the nodes in the graph correspond to indices in the DataFrame
        data.loc[(data['source'] == node) | (data['target'] == node), 'community'] = i + 1
        longitudes.append(graph.nodes[node]['longitude'])
        latitudes.append(graph.nodes[node]['latitude'])
    centroid_longitude = sum(longitudes) / len(longitudes)
    centroid_latitude = sum(latitudes) / len(latitudes)
    centroids.append((centroid_longitude, centroid_latitude))

    # Calculate the average distance from the centroid to the nodes in the community
    distances = [geodesic((lat, lon), (centroid_latitude, centroid_longitude)).meters for lat, lon in zip(latitudes, longitudes)]
    average_radius = sum(distances) / len(distances)
    radii.append(average_radius)

# Create a Folium map centered around the average location of all centroids
average_longitude = sum([c[0] for c in centroids]) / len(centroids)
average_latitude = sum([c[1] for c in centroids]) / len(centroids)
m = folium.Map(location=[average_latitude, average_longitude], zoom_start=12)

# Add community nodes to the map
for i, community in enumerate(communities):
    for node in community:
        folium.CircleMarker(
            location=[graph.nodes[node]['latitude'], graph.nodes[node]['longitude']],
            radius=3,
            color=colors[i % len(colors)],
            fill=True,
            fill_color=colors[i % len(colors)]
        ).add_to(m)

# Add centroids and radius circles to the map
for i, (centroid, radius) in enumerate(zip(centroids, radii)):
    folium.Marker(
        location=[centroid[1], centroid[0]],
        popup=f'Community {i+1} Centroid',
        icon=folium.Icon(color=colors[i % len(colors)])
    ).add_to(m)
    folium.Circle(
        location=[centroid[1], centroid[0]],
        radius=radius,
        color=colors[i % len(colors)],
        fill=True,
        fill_opacity=0.2
    ).add_to(m)

# Save the map to an HTML file
m.save('communities_map.html')

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98a6f8d73351d20724690c6350bd79a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98a6f8d73351d20724690c6350bd79a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98a6f8d73351d20724690c6350bd79a2 = L.map(
#                 &quot;map_98a6f8d73351d20724690c6350bd79a2&quot;,
#                 {
#                     center: [41.886989111760855, -87.64823902546507],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb13fe293710325eae6f00ae0434ebb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cb13fe293710325eae6f00ae0434ebb1.addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_ccccbc9886ecfb3332ad2243b2853617 = L.circleMarker(
#                 [41.878724, -87.634793],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_bd36b8ebc6d0335a8ab2f1bd33e5155b = L.circleMarker(
#                 [41.882664, -87.63253],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_d3a7bea8e332d3ffb7c82f5a55a3541d = L.circleMarker(
#                 [41.88871604, -87.64444785],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_133b85b71333a4a717e6b4efe4c6ce17 = L.circleMarker(
#                 [41.893992, -87.629318],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_9a67c8bc62988caa10a8a70dc90ef1f9 = L.circleMarker(
#                 [41.891795, -87.658751],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_f43c1cd321bacb2a0798198b6af5492a = L.circleMarker(
#                 [41.882242, -87.641066],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98a6f8d73351d20724690c6350bd79a2);
#
#
#             var circle_marker_13a87a117b105c5ff40917155b731267 = L.circleMarker(
#                 [41.872373, -87.633523],
#                 {&quot;bubblin

# %%
data.tail()
# Out:
#         TRIP ID      START TIME       STOP TIME  BIKE ID  TRIP DURATION  \
# 652624  2007267  6/7/2014 16:15  6/7/2014 16:40     2794           1513
# 652625  2007268  6/7/2014 16:15  6/7/2014 16:44      670           1740
# 652626  2007269  6/7/2014 16:15  6/7/2014 16:20     1194            288
# 652627  2007270  6/7/2014 16:15  6/7/2014 16:33      466           1094
# 652628  2007271  6/7/2014 16:15  6/7/2014 16:26     1279            643
#
#         FROM STATION ID                     source  TO STATION ID  \
# 652624               35  Streeter Dr & Illinois St            143
# 652625              177        Theater on the Lake            219
# 652626               44     State St & Randolph St             44
# 652627               94    Clark St & Armitage Ave            327
# 652628              126       Clark St & North Ave            110
#
#                              target   USER TYPE  ...  TO LONGITUDE  \
# 652624    Sedgwick St & Webster Ave    Customer  ...    -87.638888
# 652625      Damen Ave & Cortland St    Customer  ...    -87.677411
# 652626       State St & Randolph St  Subscriber  ...    -87.627734
# 652627  Sheffield Ave & Webster Ave  Subscriber  ...    -87.653818
# 652628           State St & Erie St  Subscriber  ...    -87.629318
#
#                          TO LOCATION         SourceArea           TargetArea  \
# 652624  POINT (-87.638888 41.922167)      Streeterville   Mid-North District
# 652625  POINT (-87.677411 41.916027)       Lincoln Park             Bucktown
# 652626   POINT (-87.627734 41.88473)       Chicago Loop         Chicago Loop
# 652627   POINT (-87.653818 41.92154)  Old Town Triangle  Sheffield Neighbors
# 652628  POINT (-87.629318 41.893992)       Lincoln Park           Near North
#
#         SourceMedianIncome TargetMedianIncome SourceProximityIndex  \
# 652624              117344             123004             0.881088
# 652625              123610             117152             0.557519
# 652626              123115             123115             0.960525
# 652627              123610             204211             0.628310
# 652628              123610              52011             0.697847
#
#        TargetProximityIndex  Community  community
# 652624             0.585680         -1        4.0
# 652625             0.539677         -1        5.0
# 652626             0.960525         -1        1.0
# 652627             0.562821         -1        4.0
# 652628             0.876996         -1        4.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Creating the model

# %% [markdown]
# This code trains a neural network model to classify community labels based on a proximity index from a dataset. It starts by preparing the data, creating a `proximity_value` feature, and encoding community labels. The data is split into training and testing sets, with the features standardized for effective learning.
#
# A neural network is defined with multiple layers, using ReLU activation, batch normalization, and dropout to prevent overfitting. The model is compiled with the Adam optimizer and trained for 100 epochs, monitoring both training and validation performance.
#
# After training, the model's accuracy is evaluated on the test set. The model and the scaler are saved for future use, and the training process is visualized through accuracy and loss plots. Predictions are made on the test set, and the results are analyzed using a confusion matrix, displayed as a heatmap. Finally, the model is archived into a zip file for easy distribution or deployment.

# %%
# Prepare the data for modeling
data['proximity_value'] = data['SourceProximityIndex']
features = data[['proximity_value']]
labels = data['community']

# Encode the zone labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, encoded_labels, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the history
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy on test data:", accuracy)

# Save the model
model.save('bike_sharing_model.h5')

# Save the scaler
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# Predict the labels for the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Create a zip file of the model
shutil.make_archive('bike_sharing_model', 'zip', 'bike_sharing_model')
# Out:
# Epoch 1/100
# 13053/13053 [==============================] - 29s 2ms/step - loss: 1.0607 - accuracy: 0.5847 - val_loss: 1.0180 - val_accuracy: 0.6195
# Epoch 2/100
# 13053/13053 [==============================] - 28s 2ms/step - loss: 0.9987 - accuracy: 0.6203 - val_loss: 0.9828 - val_accuracy: 0.6319
# Epoch 3/100
# 13053/13053 [==============================] - 28s 2ms/step - loss: 0.9547 - accuracy: 0.6458 - val_loss: 0.9596 - val_accuracy: 0.6446
# Epoch 4/100
# 13053/13053 [==============================] - 27s 2ms/step - loss: 0.9234 - accuracy: 0.6614 - val_loss: 0.8980 - val_accuracy: 0.6786
# Epoch 5/100
# 13053/13053 [==============================] - 29s 2ms/step - loss: 0
100
# 13053/13053 [==============================] - 28s 2ms/step - loss: 0.7385 - accuracy: 0.7499 - val_loss: 0.7273 - val_accuracy: 0.7556
# Epoch 99/100
# 13053/13053 [==============================] - 28s 2ms/step - loss: 0.7356 - accuracy: 0.7523 - val_loss: 0.7267 - val_accuracy: 0.7612
# Epoch 100/100
# 13053/13053 [==============================] - 29s 2ms/step - loss: 0.7367 - accuracy: 0.7509 - val_loss: 0.7272 - val_accuracy: 0.7563
# 4079/4079 [==============================] - 5s 1ms/step - loss: 0.7256 - accuracy: 0.7561
# Accuracy on test data: 0.7561022043228149
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4079/4079 [==============================] - 5s 1ms/step
# '/content/bike_sharing_model.zip'

# %% [markdown]
# ## Model Accuracy and Loss:
# ![image.png](attachment:image.png)
#
#
# **Accuracy:** The training and validation accuracy curves show a positive trend, stabilizing around 75%, which is a good sign that the model is learning effectively. The validation accuracy is closely aligned with the training accuracy, suggesting that the model is generalizing well to new, unseen data without significant overfitting.
#
# **Loss:** Both the training and validation loss curves steadily decrease, which is encouraging. However, I noticed some spikes in the validation loss around epochs 40 and 50, which might indicate the model is struggling with certain variations in the data, although it does recover afterwards.
#
# ## Confusion Matrix:
# ![image-2.png](attachment:image-2.png)
#
# **Class 1:** The model is performing exceptionally well on class 1, with 37,977 correct predictions and very few misclassifications. This shows that the model is highly accurate in identifying instances of this class.
#
# **Class 4:** The performance is also strong for class 4, with 31,515 correct predictions. However, there are some misclassifications, particularly with classes 2 and 5, indicating some confusion between these classes.
#
# **Other Classes (2, 3, 5):** The model shows more variation in performance with these classes. For example:
# - **Class 2** has significant confusion with classes 1 and 4, resulting in fewer correct predictions (14,732).
# - **Class 3** has some misclassifications, with a notable number of instances incorrectly labeled as classes 2 or 4.
# - **Class 5** has the fewest correct predictions (10,566), with notable misclassifications into classes 4 and 2.
#
# ## Overall Assessment:
#
# **Strengths:** The model performs well for certain classes, particularly class 1 and class 4, with high accuracy and low confusion with other classes.
#
# **Weaknesses:** The spikes in validation loss indicate some instability, and the confusion matrix shows that the model struggles to differentiate between certain classes, especially class 2 and class 5.
#
# ## Conclusion:
#
# Overall, the model is performing well, particularly in distinguishing the dominant classes. However, there is still room for improvement, especially in stabilizing the validation loss and reducing misclassification between specific classes. Further tuning, additional data, or exploring different modeling techniques might be necessary to enhance its overall performance.

# %% [markdown]
# ### Trying the model
#
# This code snippet is designed to predict a community zone in Chicago based on a given proximity value using a pre-trained machine learning model. It begins by loading a TensorFlow/Keras model and a scaler object, which were previously trained and saved. A sample proximity value is prepared as input and scaled to match the model’s training data format. The model then predicts the community zone by generating a probability distribution across different classes, selecting the zone with the highest probability. The coordinates and radius of the predicted zone are retrieved, and a Folium map is created, centered on these coordinates. A marker is placed at the centroid, and a circle representing the zone’s radius is drawn around it. The resulting map is saved as an HTML file and can also be displayed interactively. This process seamlessly integrates machine learning predictions with geospatial visualization, providing a clear, interactive representation of the predicted community zone in Chicago.

# %%
# Load the trained model and scaler
model = tf.keras.models.load_model('bike_sharing_model.h5')
with open('scaler.pkl', 'rb') as file:
    scaler = pickle.load(file)

# Assuming `data` is available and has columns 'community' and 'proximity_value'

# Prepare a sample input for prediction
sample_proximity_value = 0.98  # Example proximity value
sample_features = pd.DataFrame({'proximity_value': [sample_proximity_value]})

# Scale the sample features
scaled_sample_features = scaler.transform(sample_features)

# Predict the community zone
predicted_prob = model.predict(scaled_sample_features)
predicted_class = np.argmax(predicted_prob, axis=1)
predicted_class
# Coordinates and radius for the zone in Chicago
coordinates = centroids[predicted_class[0] -1 ]
radius = radii[predicted_class[0] -1 ]

# Create a Folium map centered around the given coordinates
m = folium.Map(location=[coordinates[1], coordinates[0]], zoom_start=14)

# Add the centroid and radius circle to the map
folium.Marker(
    location=[coordinates[1], coordinates[0]],
    popup='Predicted Zone Centroid',
    icon=folium.Icon(color='blue')
).add_to(m)

folium.Circle(
    location=[coordinates[1], coordinates[0]],
    radius=radius,  # radius in meters
    color='blue',
    fill=True,
    fill_opacity=0.2
).add_to(m)

# Save the map to an HTML file
m.save('chicago_zone_map.html')

# Display the map
m
# Out:
# 1/1 [==============================] - 0s 70ms/step
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13bc14d9ba3f6f1159bf30b663362222 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13bc14d9ba3f6f1159bf30b663362222&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13bc14d9ba3f6f1159bf30b663362222 = L.map(
#                 &quot;map_13bc14d9ba3f6f1159bf30b663362222&quot;,
#                 {
#                     center: [41.90844586829786, -87.67549568553193],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d9197bd63946efae6410a57e975a442 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d9197bd63946efae6410a57e975a442.addTo(map_13bc14d9ba3f6f1159bf30b663362222);
#
#
#             var marker_a9f16336af02f62a7715fdebb28c3a58 = L.marker(
#                 [41.90844586829786, -87.67549568553193],
#                 {}
#             ).addTo(map_13bc14d9ba3f6f1159bf30b663362222);
#
#
#             var icon_9dfccf900d9053e0bf289c202ff758aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9f16336af02f62a7715fdebb28c3a58.setIcon(icon_9dfccf900d9053e0bf289c202ff758aa);
#
#
#         var popup_e8b17d421628f59fe0b288eb0215b5f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18bcda9f1fcfb0d9328b81df31154bee = $(`&lt;div id=&quot;html_18bcda9f1fcfb0d9328b81df31154bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Zone Centroid&lt;/div&gt;`)[0];
#                 popup_e8b17d421628f59fe0b288eb0215b5f8.setContent(html_18bcda9f1fcfb0d9328b81df31154bee);
#
#
#
#         marker_a9f16336af02f62a7715fdebb28c3a58.bindPopup(popup_e8b17d421628f59fe0b288eb0215b5f8)
#         ;
#
#
#
#
#             var circle_6966bd71189c255e80b0390fc2397cc6 = L.circle(
#                 [41.90844586829786, -87.67549568553193],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1588.9685603075486, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13bc14d9ba3f6f1159bf30b663362222);
#
#
#             tile_layer_8d9197bd63946efae6410a57e975a442.addTo(map_13bc14d9ba3f6f1159bf30b663362222);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Save the output in zip and download it

# %%
# !zip -r finalYes.zip /content/model_final
# Out:
#   adding: content/model_final/ (stored 0%)
#   adding: content/model_final/start_centroids.npy (deflated 15%)
#   adding: content/model_final/bike_sharing_model.zip (stored 0%)
#   adding: content/model_final/scaler.pkl (deflated 32%)
#   adding: content/model_final/end_centroids.npy (deflated 15%)
#   adding: content/model_final/bike_sharing_model.h5 (deflated 35%)
#   adding: content/model_final/chicago_zone_map.html (deflated 66%)
#   adding: content/model_final/communities_map.html (deflated 92%)
#   adding: content/model_final/best_model.h5 (deflated 36%)
